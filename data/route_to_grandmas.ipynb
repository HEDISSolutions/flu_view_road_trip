# %%
import pandas as pd
import os

# Relative path for the input file
input_file = os.path.join("data", "StateDatabyWeek.csv")

# Relative path for the output file
output_folder = "output"
os.makedirs(output_folder, exist_ok=True)  # Ensure the output folder exists
output_file = os.path.join(output_folder, "Route_to_Grandmas.csv")

# List of states to keep (rename the dictionary)
route_to_grandmas = ["California", "Nevada", "New Mexico", "Texas", "Alabama", "Louisiana", "Florida"]

# Load the CSV file
df = pd.read_csv(input_file)

# Filter rows to keep only those where STATENAME is in route_to_grandmas
filtered_df = df[df['STATENAME'].isin(route_to_grandmas)]

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv(output_file, index=True)


filtered_df
# Out:
#       STATENAME                                                URL  \
# 0       Alabama                         http://adph.org/influenza/
# 4    California  https://www.cdph.ca.gov/Programs/CID/DCDC/Page...
# 9       Florida  http://www.floridahealth.gov/diseases-and-cond...
# 18    Louisiana           https://ldh.la.gov/page/respiratory-home
# 28       Nevada      http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# ..          ...                                                ...
# 889     Florida  http://www.floridahealth.gov/diseases-and-cond...
# 898   Louisiana           https://ldh.la.gov/page/respiratory-home
# 908      Nevada      http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# 911  New Mexico           https://nmhealth.org/about/erd/ideb/isp/
# 923       Texas  http://www.dshs.state.tx.us/idcu/disease/influ...
#
#                                                WEBSITE ACTIVITY LEVEL  \
# 0                               Influenza Surveillance       Level 12
# ...

# %%
# Ensure the 'ACTIVITY LEVEL' column is of type string, remove 'LEVEL', and convert values to integers
filtered_df.loc[:, 'ACTIVITY LEVEL'] = (
    filtered_df['ACTIVITY LEVEL']
    .astype(str)  # Ensure the column is of type string
    .str.replace('LEVEL', '', case=False, regex=False)  # Remove 'LEVEL'
    .str.strip()  # Remove whitespace
    .astype(int)  # Convert cleaned values to integers
)

# Define the path for the new CSV file
new_output_file = os.path.join("data", "route_to_grandmas.csv")

# Save the filtered DataFrame to the new CSV file
filtered_df.to_csv(new_output_file, index=True)

filtered_df
# Out:
#       STATENAME                                                URL  \
# 0       Alabama                         http://adph.org/influenza/
# 4    California  https://www.cdph.ca.gov/Programs/CID/DCDC/Page...
# 9       Florida  http://www.floridahealth.gov/diseases-and-cond...
# 18    Louisiana           https://ldh.la.gov/page/respiratory-home
# 28       Nevada      http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# ..          ...                                                ...
# 889     Florida  http://www.floridahealth.gov/diseases-and-cond...
# 898   Louisiana           https://ldh.la.gov/page/respiratory-home
# 908      Nevada      http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# 911  New Mexico           https://nmhealth.org/about/erd/ideb/isp/
# 923       Texas  http://www.dshs.state.tx.us/idcu/disease/influ...
#
#                                                WEBSITE  ACTIVITY LEVEL  \
# 0                               Influenza Surveillance              12
# ...

# %%
import pandas as pd
import os

# Define the input file as the file in the current directory
input_file = "route_to_grandmas.csv"
#>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>AI Consulting<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Define the output file path in the parent `output` folder
output_folder = "../output"
os.makedirs(output_folder, exist_ok=True)  # Ensure the output folder exists
output_file = os.path.join(output_folder, "filtered_route_to_grandmas.csv")

# Debugging: Verify the full path of the input file
print(f"Input file: {os.path.abspath(input_file)}")
#>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>AI Consulting<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Load the dataset
df = pd.read_csv(input_file)

# Convert WEEKEND column to datetime
df['WEEKEND'] = pd.to_datetime(df['WEEKEND'])

# Filter out rows where the WEEKEND column is between Jan-06-2024 and Feb-29-2024
df_filtered = df[
    (df['WEEKEND'] < pd.to_datetime('2024-01-06')) | 
    (df['WEEKEND'] > pd.to_datetime('2024-02-29'))
]

df_filtered
# Out:
# Input file: c:\Users\board\PROJECT_3_FLUVIEW\data\route_to_grandmas.csv
#      Unnamed: 0   STATENAME  \
# 56          440     Alabama
# 57          444  California
# 58          449     Florida
# 59          458   Louisiana
# 60          468      Nevada
# ..          ...         ...
# 114         889     Florida
# 115         898   Louisiana
# 116         908      Nevada
# 117         911  New Mexico
# 118         923       Texas
#
#                                                    URL  \
# 56                          http://adph.org/influenza/
# 57   https://www.cdph.ca.gov/Programs/CID/DCDC/Page...
# 58   http://www.floridahealth.gov/diseases-and-cond...
# 59            https://ldh.la.gov/page/respiratory-home
# 60       http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# ..                                                 ...
# 114  http://www.floridahealth.gov/diseases-and-cond...
# 115           https://ldh.la.gov/page/respiratory-home
# ...

# %%
# Check if the columns exist before attempting to drop them
columns_to_drop = ['Unnamed: 0',]

df_filtered
# Out:
#       STATENAME                                                URL  \
# 56      Alabama                         http://adph.org/influenza/
# 57   California  https://www.cdph.ca.gov/Programs/CID/DCDC/Page...
# 58      Florida  http://www.floridahealth.gov/diseases-and-cond...
# 59    Louisiana           https://ldh.la.gov/page/respiratory-home
# 60       Nevada      http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# ..          ...                                                ...
# 114     Florida  http://www.floridahealth.gov/diseases-and-cond...
# 115   Louisiana           https://ldh.la.gov/page/respiratory-home
# 116      Nevada      http://dpbh.nv.gov/Programs/Flu/Influenza/%20
# 117  New Mexico           https://nmhealth.org/about/erd/ideb/isp/
# 118       Texas  http://www.dshs.state.tx.us/idcu/disease/influ...
#
#                                                WEBSITE  ACTIVITY LEVEL  \
# 56                              Influenza Surveillance               7
# ...

# %%
# Save the filtered DataFrame to a new CSV file
df_filtered.to_csv(output_file, index=True)
